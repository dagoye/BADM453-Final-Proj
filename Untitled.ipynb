# %%
#BADM FINAL PROJECT

# %%
#Import Required Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#Import 'Singapore AirBNB' Dataset

df = pd.read_csv('listings_full.csv')
df.head()
df.info() #last_review and reviews_per month having missing values(5149/7907)
df.isnull().sum() #name has 2 null values and last_review and reviews_per month have 2758
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7675 entries, 0 to 7674
# Data columns (total 36 columns):
# id                                7675 non-null int64
# name                              7673 non-null object
# description                       7514 non-null object
# host_id                           7675 non-null int64
# host_name                         7674 non-null object
# host_response_time                6272 non-null object
# host_response_rate                6272 non-null float64
# host_is_superhost                 7674 non-null object
# host_total_listings_count         7674 non-null float64
# host_identity_verified            7674 non-null object
# neighbourhood                     7675 non-null object
# neighbourhood_group_cleansed      7675 non-null object
# latitude                          7675 non-null float64
# longitude                         7675 non-null float64
# property_type                     7675 non-null object
# ...

# %%
#Cleaning and Preprocessing Dataset

df.head()

#---Encoding

#----Categorical Variables - neighbourhood_group, neigbourhood(?), room_type, last_review (?)


#drop...

drop = ['id', 'name', 'host_id', 'host_name','description','neighbourhood','latitude','longitude','c']

id, name, host_id, host_name, description, neighbourhood, latitude, longitude, calculated_host_listing counts_
# Out:
#       id                                 name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2
# 1  50646      Pleasant Room along Bukit Timah
# 2  56334                          COZICOMFORT
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO
# 4  71896      B&B  Room 1 near Airport & EXPO
#
#                                          description  host_id  host_name  \
# 0  This is Room No. 2.(available after Jan 15 201...   266763  Francesca
# 1  Fully furnished bedroom with a nice view on th...   227796    Sujatha
# 2  This is Room no. 1. USD700 per month On the fa...   266763  Francesca
# 3  For 3 (Website hidden by Airbnb) room 1&2 and ...   367042    Belinda
# 4  Vocational Stay Deluxe Bedroom in Singapore.(N...   367042    Belinda
#
#    host_response_time  host_response_rate host_is_superhost  \
# 0  within a few hours                 1.0                 f
# 1                 NaN                 NaN                 f
# 2  within a few hours                 1.0                 f
# ...

# %%
#Feature Selection (Which features actually impact --)

df['host_response_time'].sort_values().count()

df.groupby(['host_response_time']).count()

df.groupby(['room_type']).count()

df.groupby(['cancellation_policy']).count()
# Out:
#                                id  name  description  host_id  host_name  \
# cancellation_policy
# flexible                     1601  1599         1491     1601       1601
# moderate                     1060  1060         1048     1060       1060
# strict                          1     1            1        1          1
# strict_14_with_grace_period  4988  4988         4949     4988       4987
# super_strict_30                18    18           18       18         18
# super_strict_60                 7     7            7        7          7
#
#                              host_response_time  host_response_rate  \
# cancellation_policy
# flexible                                    826                 826
# moderate                                    828                 828
# strict                                        1                   1
# strict_14_with_grace_period                4592                4592
# super_strict_30                              18                  18
# ...

# %%
import patsy

#

host_response_time = patsy.dmatrix('C(host_response_time)-1', df, return_type='dataframe')
host_response_time

df2 = pd.concat([df, host_response_time], axis=1)
df2

#should
# Out:
#             id                                               name  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2
# 1        50646                    Pleasant Room along Bukit Timah
# 2        56334                                        COZICOMFORT
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO
# 4        71896                    B&B  Room 1 near Airport & EXPO
# 5        71903                         Room 2-near Airport & EXPO
# 6        71907                   3rd level Jumbo room 5 near EXPO
# 7       241503             Long stay at The Breezy East "Leopard"
# 8       241508            Long stay at The Breezy East "Plumeria"
# 9       241510            Long stay at The Breezy East "Red Palm"
# 10      275343  Conveniently located City Room!( (Phone number...
# 11      275344              15 mins to Outram MRT Single Room (B)
# 12      289234                             Booking for 3 bedrooms
# ...
